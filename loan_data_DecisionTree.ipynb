# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier

# %%
df = pd.read_csv('loan_data.CSV')

# %%
df.head()
# Out:
#    person_age person_gender person_education  person_income  person_emp_exp  \
# 0        22.0        female           Master        71948.0               0
# 1        21.0        female      High School        12282.0               0
# 2        25.0        female      High School        12438.0               3
# 3        23.0        female         Bachelor        79753.0               0
# 4        24.0          male           Master        66135.0               1
#
#   person_home_ownership  loan_amnt loan_intent  loan_int_rate  \
# 0                  RENT    35000.0    PERSONAL          16.02
# 1                   OWN     1000.0   EDUCATION          11.14
# 2              MORTGAGE     5500.0     MEDICAL          12.87
# 3                  RENT    35000.0     MEDICAL          15.23
# 4                  RENT    35000.0     MEDICAL          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# ...

# %%
dff = pd.get_dummies(df,drop_first=True) 
dff.head()
# Out:
#    person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0        22.0        71948.0               0    35000.0          16.02
# 1        21.0        12282.0               0     1000.0          11.14
# 2        25.0        12438.0               3     5500.0          12.87
# 3        23.0        79753.0               0    35000.0          15.23
# 4        24.0        66135.0               1    35000.0          14.27
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status  \
# 0                 0.49                         3.0           561            1
# 1                 0.08                         2.0           504            0
# 2                 0.44                         3.0           635            1
# 3                 0.44                         2.0           675            1
# 4                 0.53                         4.0           586            1
#
#    person_gender_male  ...  person_education_Master  \
# ...

# %%
dff= dff.astype(int) 
dff.head()
# Out:
#    person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0          22          71948               0      35000             16
# 1          21          12282               0       1000             11
# 2          25          12438               3       5500             12
# 3          23          79753               0      35000             15
# 4          24          66135               1      35000             14
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status  \
# 0                    0                           3           561            1
# 1                    0                           2           504            0
# 2                    0                           3           635            1
# 3                    0                           2           675            1
# 4                    0                           4           586            1
#
#    person_gender_male  ...  person_education_Master  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

column = ['person_age',	'person_income','person_emp_exp','loan_amnt','loan_int_rate','cb_person_cred_hist_length','credit_score'] 
scaler = StandardScaler() 
dff[column] = scaler.fit_transform(dff[column]) 
dff.head()
# Out:
#    person_age  person_income  person_emp_exp  loan_amnt  loan_int_rate  \
# 0   -0.953538      -0.104090       -0.892284   4.024953       1.828999
# 1   -1.118963      -0.846005       -0.892284  -1.359209       0.168721
# 2   -0.457264      -0.844065       -0.397517  -0.646600       0.500777
# 3   -0.788113      -0.007039       -0.892284   4.024953       1.496943
# 4   -0.622689      -0.176371       -0.727362   4.024953       1.164888
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  loan_status  \
# 0                    0                   -0.739109     -1.419814            1
# 1                    0                   -0.996863     -2.549975            0
# 2                    0                   -0.739109      0.047412            1
# 3                    0                   -0.996863      0.840507            1
# 4                    0                   -0.481354     -0.924130            1
#
#    person_gender_male  ...  person_education_Master  \
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %%
x =dff.drop('loan_status',axis=1) 
y = dff['loan_status']

# %%
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size = 0.3,random_state=30)

# %%
stander = StandardScaler() 
x_train_scal = stander.fit_transform(x_train) 
x_test_scal = stander.transform(x_test)

# %%
models= {
    "logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Byeas": GaussianNB(), 
    "Decission": DecisionTreeClassifier(), 
    "SVM": SVC(probability=True)
                 }

# %%
results= []

# %%
for name, model in models.items():
    model.fit(x_train_scal, y_train)
    y_pred = model.predict(x_test_scal)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    results.append({
        'Model': name,
        'Accuracy': round(acc, 4),
        'F1 Score': round(f1, 4)
    })

# %%
results
# Out:
# [{'Model': 'logistic Regression', 'Accuracy': 0.8847, 'F1 Score': 0.7414},
#  {'Model': 'KNN', 'Accuracy': 0.8647, 'F1 Score': 0.6798},
#  {'Model': 'Naive Byeas', 'Accuracy': 0.7473, 'F1 Score': 0.6311},
#  {'Model': 'Decission', 'Accuracy': 0.8966, 'F1 Score': 0.7691},
#  {'Model': 'SVM', 'Accuracy': 0.905, 'F1 Score': 0.7789}]

# %%
df.describe()
# Out:
#          person_age  person_gender  person_education  person_income  \
# count  45000.000000   45000.000000      45000.000000   4.500000e+04
# mean      27.764178       0.552022          1.743933   8.031905e+04
# std        6.045108       0.497292          1.479148   8.042250e+04
# min       20.000000       0.000000          0.000000   8.000000e+03
# 25%       24.000000       0.000000          0.000000   4.720400e+04
# 50%       26.000000       1.000000          1.000000   6.704800e+04
# 75%       30.000000       1.000000          3.000000   9.578925e+04
# max      144.000000       1.000000          4.000000   7.200766e+06
#
#        person_emp_exp  person_home_ownership     loan_amnt   loan_intent  \
# count    45000.000000           45000.000000  45000.000000  45000.000000
# mean         5.410333               1.696622   9583.157556      2.525911
# std          6.063532               1.440497   6314.886691      1.728305
# ...

# %%
cols = ['person_gender','person_education','person_home_ownership','loan_intent','previous_loan_defaults_on_file']
le = LabelEncoder()

for col in cols: 
 df[col] = le.fit_transform(df[col])

# %%
df.head(3)
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0        22.0              0                 4        71948.0               0
# 1        21.0              0                 3        12282.0               0
# 2        25.0              0                 3        12438.0               3
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0                      3    35000.0            4          16.02
# 1                      2     1000.0            1          11.14
# 2                      0     5500.0            3          12.87
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# 0                 0.49                         3.0           561
# 1                 0.08                         2.0           504
# 2                 0.44                         3.0           635
#
#    previous_loan_defaults_on_file  loan_status
# 0                               0            1
# ...

# %%
col_to_scal =['person_age','person_education','person_income','person_emp_exp','person_home_ownership','loan_amnt','loan_intent','loan_int_rate','loan_percent_income','cb_person_cred_hist_length','cb_person_cred_hist_length','credit_score']

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df[col_to_scal] = scaler.fit_transform(df[col_to_scal])

# %%
col_to_scal
# Out:
# ['person_age',
#  'person_education',
#  'person_income',
#  'person_emp_exp',
#  'person_home_ownership',
#  'loan_amnt',
#  'loan_intent',
#  'loan_int_rate',
#  'loan_percent_income',
#  'cb_person_cred_hist_length',
#  'cb_person_cred_hist_length',
#  'credit_score']

# %%
for col in df: 
    print(f'{col}:{df[col].unique()}') 
# for col in df2:
#     print(f'{col}: {df2[col].unique()}')
# Out:
# person_age:[0.01612903 0.00806452 0.04032258 0.02419355 0.03225806 0.0483871
#  1.         0.83064516 0.         0.09677419 0.11290323 0.07258065
#  0.10483871 0.06451613 0.12096774 0.08870968 0.05645161 0.08064516
#  0.12903226 0.16129032 0.24193548 0.2016129  0.13709677 0.15322581
#  0.19354839 0.18548387 0.16935484 0.20967742 0.14516129 0.21774194
#  0.17741935 0.22580645 0.23387097 0.30645161 0.36290323 0.25
#  0.26612903 0.37096774 0.33064516 0.27419355 0.2983871  0.31451613
#  0.33870968 0.32258065 0.28225806 0.25806452 0.35483871 0.40322581
#  0.46774194 0.39516129 0.29032258 0.42741935 0.34677419 0.59677419
#  0.48387097 0.51612903 0.4516129  0.37903226 0.77419355 0.71774194]
# person_gender:[0 1]
# person_education:[1.   0.75 0.25 0.   0.5 ]
# person_income:[0.0088906  0.00059532 0.00061701 ... 0.00332612 0.00680434 0.00349852]
# person_emp_exp:[0.    0.024 0.008 0.04  0.032 0.016 0.056 0.048 1.    0.064 0.968 0.808
# ...

# %%
df= pd.DataFrame(df)
df.head()
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0    0.016129              0              1.00       0.008891           0.000
# 1    0.008065              0              0.75       0.000595           0.000
# 2    0.040323              0              0.75       0.000617           0.024
# 3    0.024194              0              0.25       0.009976           0.000
# 4    0.032258              1              1.00       0.008082           0.008
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0               1.000000   1.000000          0.8       0.727023
# 1               0.666667   0.014493          0.2       0.392318
# 2               0.000000   0.144928          0.6       0.510974
# 3               1.000000   1.000000          0.6       0.672840
# 4               1.000000   1.000000          0.6       0.606996
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# ...

# %%
df = pd.get_dummies(df,drop_first = True)
df.head()
# Out:
#    person_age  person_gender  person_education  person_income  person_emp_exp  \
# 0    0.016129              0              1.00       0.008891           0.000
# 1    0.008065              0              0.75       0.000595           0.000
# 2    0.040323              0              0.75       0.000617           0.024
# 3    0.024194              0              0.25       0.009976           0.000
# 4    0.032258              1              1.00       0.008082           0.008
#
#    person_home_ownership  loan_amnt  loan_intent  loan_int_rate  \
# 0               1.000000   1.000000          0.8       0.727023
# 1               0.666667   0.014493          0.2       0.392318
# 2               0.000000   0.144928          0.6       0.510974
# 3               1.000000   1.000000          0.6       0.672840
# 4               1.000000   1.000000          0.6       0.606996
#
#    loan_percent_income  cb_person_cred_hist_length  credit_score  \
# ...

# %%
x= df.drop('loan_status', axis='columns') 
y = df['loan_status'] 
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=20)

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(x_train)

# %%
print("\nScaled Features (MinMaxScaler):\n", X_scaled)
# Out:
# Scaled Features (MinMaxScaler):
#  [[0.14563107 0.         0.         ... 0.14285714 0.57831325 1.        ]
#  [0.19417476 1.         0.75       ... 0.53571429 0.57108434 1.        ]
#  [0.01941748 1.         0.75       ... 0.         0.40240964 1.        ]
#  ...
#  [0.13592233 1.         0.         ... 0.21428571 0.52771084 1.        ]
#  [0.02912621 0.         0.75       ... 0.07142857 0.62409639 0.        ]
#  [0.06796117 1.         0.25       ... 0.14285714 0.75662651 0.        ]]

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([1, 0, 0, ..., 0, 1, 0], shape=(13500,))

# %%
print("\nPredictions:", y_pred)
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Predictions: [1 0 0 ... 0 1 0]
# Accuracy: 0.8905925925925926

# %%
models = {
    "Random Forest": RandomForestClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(),
    "Neural Network (MLP)": MLPClassifier(max_iter=1000),
    "XGBoost": XGBClassifier(eval_metric='logloss'),
    
}

# %%
results = {}

for name, model in models.items():
    model.fit(x_train, y_train)
    pred = model.predict(x_test)
    acc = accuracy_score(y_test, pred)
    results[name] = acc

# %%
for model_name, acc in results.items():
    print(f"{model_name}: {acc:.4f}")
# Out:
# Random Forest: 0.9257
# Gradient Boosting: 0.9212
# Neural Network (MLP): 0.9139
# XGBoost: 0.9302

# %%
best_model = max(results, key=results.get)
print("BEST MODEL =", best_model, "| Accuracy =", results[best_model])
# Out:
# BEST MODEL = XGBoost | Accuracy = 0.9302222222222222

# %%
plt.figure(figsize=(6,4))
df['loan_status'].value_counts().plot(kind='bar')
plt.title("Loan Status Counts")
plt.xlabel("Loan Status")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(data=df, x='person_income', y='loan_amnt', hue='loan_status')
plt.title("Income vs Loan Amount")
plt.show()

# %%
df.isnull().sum()

# %%
X = df.drop('loan_status',axis= 1) 
y =df['loan_status']

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=30)

# %%
print('x_train:',X_train)
print('x_test:',X_test)
print('y_train:',y_train) 
print('y_test:',y_test)

# %%
model = DecisionTreeClassifier( 
    criterion="gini",
    max_depth=7,
    min_samples_leaf=5,
    random_state= 5
)

# %%
model.fit(X_train,y_train)

# %%
pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, pred))
print("\nClassification Report:\n", classification_report(y_test, pred))

# %%
importances = pd.Series(model.feature_importances_, index=X.columns)
print("\nFeature Importance:\n", importances.sort_values(ascending=False))

# %%
model.score(x_test,y_test)

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier(max_depth=5)
dt.fit(x, y)

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,10))
plot_tree(dt, feature_names=x.columns, filled=True)
plt.show()
